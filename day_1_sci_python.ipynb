# %% [markdown]
# <a href="https://colab.research.google.com/github/RayyanShajahan/My-codes/blob/main/day_1_sci_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#day 1 addon
import pandas as pd

df=pd.DataFrame({
    'Name':['Asha','Ravi','Neha','Kiran'],
    'Age':[22,25,28,30],
    'Marks':[80,85,90,88]
}, index=[1, 2, 3, 4])

# %%
df
# Out:
#     Name  Age  Marks
# 1   Asha   22     80
# 2   Ravi   25     85
# 3   Neha   28     90
# 4  Kiran   30     88

# %%
data={
    'Name':['Alice','Bob','Charlie'],
    'Age':[25,30,35],
    'Salary':[50000,60000,70000],
    'Department':['IT','HR','IT']
}

df=pd.DataFrame(data)
print(df)
# Out:
#       Name  Age  Salary Department
# 0    Alice   25   50000         IT
# 1      Bob   30   60000         HR
# 2  Charlie   35   70000         IT

# %%
df=pd.read_csv('/content/Zudio_sales_data.csv')
df.head()
# Out:
#    Store Country          State      City Category Clothing Type  \
# 0  Zudio   India      Karnataka     Jalna    Women       Dresses
# 1  Zudio   India        Gujarat     Patna     Kids        Skirts
# 2  Zudio   India  Uttar Pradesh   Kolkata      Men       Hoodies
# 3  Zudio   India    West Bengal   Kolkata    Women       Dresses
# 4  Zudio   India    West Bengal  Guwahati      Men       Dresses
#
#    Store Number  Postal Code Store Type Store Open Date  ...  \
# 0            30       411084      Owned      2022-06-04  ...
# 1            48       404562      Owned      2020-12-19  ...
# 2            97       437773     Rented      2023-09-04  ...
# 3            93       431725      Owned      2024-04-11  ...
# 4            51       415370      Owned      2022-05-29  ...
#
#    Security Features Order ID  Order Date     Month Customer ID  \
# 0              Alarm    88240  2024-11-06  November      233084
# 1              Alarm    78145  2024-06-17      June      926472
# ...

# %%
df.shape
# Out:
# (2823, 25)

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2818    False
# 2819    False
# 2820    False
# 2821    False
# 2822    False
# Length: 2823, dtype: bool

# %%
filtered_rows = df[df['Country'] == 'India']
print(filtered_rows)
# Out:
#       Store Country          State        City Category Clothing Type  \
# 0     Zudio   India      Karnataka       Jalna    Women       Dresses
# 1     Zudio   India        Gujarat       Patna     Kids        Skirts
# 2     Zudio   India  Uttar Pradesh     Kolkata      Men       Hoodies
# 3     Zudio   India    West Bengal     Kolkata    Women       Dresses
# 4     Zudio   India    West Bengal    Guwahati      Men       Dresses
# ...     ...     ...            ...         ...      ...           ...
# 7894  Zudio   India  Uttar Pradesh  Chandigarh     Kids         Jeans
# 7895  Zudio   India  Uttar Pradesh  Aurangabad     Kids       Jackets
# 7896  Zudio   India     Tamil Nadu        Pune     Kids      T-shirts
# 7897  Zudio   India          Delhi     Madurai      Men         Shoes
# 7898  Zudio   India        Gujarat   Bengaluru    Women        Shirts
#
#       Store Number  Postal Code Store Type Store Open Date  ...  \
# ...

# %%
df[['Postal Code','Country']]
# Out:
#       Postal Code Country
# 0          411084   India
# 1          404562   India
# 2          437773   India
# 3          431725   India
# 4          415370   India
# ...           ...     ...
# 7894       431437   India
# 7895       424643   India
# 7896       412057   India
# 7897       405203   India
# 7898       429823   India
#
# [7899 rows x 2 columns]

# %%
df[['Country','State']]
# Out:
#      Country          State
# 0      India      Karnataka
# 1      India        Gujarat
# 2      India  Uttar Pradesh
# 3      India    West Bengal
# 4      India    West Bengal
# ...      ...            ...
# 7894   India  Uttar Pradesh
# 7895   India  Uttar Pradesh
# 7896   India     Tamil Nadu
# 7897   India          Delhi
# 7898   India        Gujarat
#
# [7899 rows x 2 columns]

# %%
df[['Store Type','State','Order ID']]
# Out:
#      Store Type          State  Order ID
# 0         Owned      Karnataka     88240
# 1         Owned        Gujarat     78145
# 2        Rented  Uttar Pradesh     33363
# 3         Owned    West Bengal     46682
# 4         Owned    West Bengal     58242
# ...         ...            ...       ...
# 7894      Owned  Uttar Pradesh     39056
# 7895      Owned  Uttar Pradesh     85486
# 7896      Owned     Tamil Nadu     78200
# 7897     Rented          Delhi     19883
# 7898      Owned        Gujarat     91451
#
# [7899 rows x 3 columns]

# %%
df['Country'].unique()
# Out:
# array(['India'], dtype=object)

# %%
df['Country'].unique()
# Out:
# array(['India'], dtype=object)

# %%
df.loc[0]
# Out:
# ORDERNUMBER                           10107
# QUANTITYORDERED                          30
# PRICEEACH                              95.7
# ORDERLINENUMBER                           2
# SALES                                2871.0
# ORDERDATE                    2/24/2003 0:00
# STATUS                              Shipped
# QTR_ID                                    1
# MONTH_ID                                  2
# YEAR_ID                                2003
# PRODUCTLINE                     Motorcycles
# MSRP                                     95
# PRODUCTCODE                        S10_1678
# CUSTOMERNAME              Land of Toys Inc.
# PHONE                            2125557818
# ADDRESSLINE1        897 Long Airport Avenue
# ADDRESSLINE2                            NaN
# CITY                                    NYC
# STATE                                    NY
# POSTALCODE                            10022
# COUNTRY                                 USA
# ...

# %%
df.loc[25,'Order Date']
# Out:
# '2024-01-18'

# %%
df.loc[25,['Order Date','State']]
# Out:
# Order Date    2024-01-18
# State          Karnataka
# Name: 25, dtype: object

# %%
df.loc[0:25,['Order Date','State']]
# Out:
#     Order Date          State
# 0   2024-11-06      Karnataka
# 1   2024-06-17        Gujarat
# 2   2024-08-17  Uttar Pradesh
# 3   2024-03-27    West Bengal
# 4   2024-04-08    West Bengal
# 5   2024-04-25    West Bengal
# 6   2024-06-19    Maharashtra
# 7   2024-06-11    West Bengal
# 8   2024-01-24      Karnataka
# 9   2024-02-02      Karnataka
# 10  2024-07-16    Maharashtra
# 11  2024-07-22  Uttar Pradesh
# 12  2024-05-17    Maharashtra
# 13  2024-05-20        Gujarat
# 14  2024-10-26     Tamil Nadu
# 15  2024-03-19      Rajasthan
# 16  2024-11-09    Maharashtra
# 17  2024-07-19      Rajasthan
# 18  2024-09-03      Rajasthan
# 19  2024-03-31      Rajasthan
# 20  2024-08-28     Tamil Nadu
# 21  2024-05-10          Delhi
# 22  2024-06-07        Gujarat
# 23  2024-05-01    West Bengal
# 24  2024-10-25      Karnataka
# 25  2024-01-18      Karnataka

# %%
df.loc[0:25,'Price']
# Out:
# 0     1958
# 1     2078
# 2     1445
# 3     2469
# 4     1105
# 5     2206
# 6     2848
# 7     1694
# 8     2024
# 9     2581
# 10    1457
# 11    2839
# 12    2592
# 13     642
# 14    2875
# 15    2922
# 16    2087
# 17    2299
# 18    2581
# 19     500
# 20    1952
# 21    2249
# 22    1873
# 23    1229
# 24    1676
# 25    1764
# Name: Price, dtype: int64

# %%
df.loc[0:25,['Price','Quantity','Sales Profit']]
# Out:
#     Price  Quantity  Sales Profit
# 0    1958         5        3916.0
# 1    2078         1         831.2
# 2    1445         2        1156.0
# 3    2469         6        5925.6
# 4    1105         6        2652.0
# 5    2206         4        3529.6
# 6    2848         4        4556.8
# 7    1694         8        5420.8
# 8    2024         1         809.6
# 9    2581         6        6194.4
# 10   1457         5        2914.0
# 11   2839         1        1135.6
# 12   2592         5        5184.0
# 13    642         8        2054.4
# 14   2875         2        2300.0
# 15   2922         8        9350.4
# 16   2087         8        6678.4
# 17   2299         3        2758.8
# 18   2581         2        2064.8
# 19    500         4         800.0
# 20   1952         3        2342.4
# 21   2249         3        2698.8
# 22   1873         2        1498.4
# 23   1229         7        3441.2
# 24   1676         7        4692.8
# 25   1764         1         705.6

# %%
df.loc[0:25,['Customer Name','City','Country']]
# Out:
#         Customer Name          City Country
# 0       Michele Ochoa         Jalna   India
# 1      Daniel Jimenez         Patna   India
# 2        Steven Davis       Kolkata   India
# 3        Derek Orozco       Kolkata   India
# 4       Victor Arnold      Guwahati   India
# 5       James Bennett        Nashik   India
# 6    Benjamin Barrett       Lucknow   India
# 7   Matthew Cervantes     Hyderabad   India
# 8       Shelley Lopez     Ahmedabad   India
# 9     Brandon Sampson     Hyderabad   India
# 10    Melissa Rowland       Kolkata   India
# 11         Thomas Lin        Nashik   India
# 12      Bruce Leonard     Faridabad   India
# 13      Tracey Barnes         Noida   India
# 14      Cindy Ramirez       Madurai   India
# 15    Courtney Morris         Noida   India
# 16        Sean Taylor  Chhattisgarh   India
# 17      Shannon Kelly     Bengaluru   India
# 18      Brenda Gordon       Kolkata   India
# 19       Mark Perkins          Agra   India
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.rename(columns={'State':'STATE_NAME'},inplace=True)

# %%
df.rename(columns={'City':'REGION'},inplace=True)

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'REGION', 'STATE_NAME', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
df['Order Date']
# Out:
# 0       2024-11-06
# 1       2024-06-17
# 2       2024-08-17
# 3       2024-03-27
# 4       2024-04-08
#            ...
# 7894    2024-09-27
# 7895    2024-03-16
# 7896    2024-12-02
# 7897    2024-07-29
# 7898    2024-04-08
# Name: Order Date, Length: 7899, dtype: object

# %%
df['Order Date']=pd.to_datetime(df['Order Date'])

# %%
df['Order Date']
# Out:
# 0      2024-11-06
# 1      2024-06-17
# 2      2024-08-17
# 3      2024-03-27
# 4      2024-04-08
#           ...
# 7894   2024-09-27
# 7895   2024-03-16
# 7896   2024-12-02
# 7897   2024-07-29
# 7898   2024-04-08
# Name: Order Date, Length: 7899, dtype: datetime64[ns]

# %%
df['YEAR']=df['Order Date'].dt.year
df['YEAR']
# Out:
# 0       2024
# 1       2024
# 2       2024
# 3       2024
# 4       2024
#         ...
# 7894    2024
# 7895    2024
# 7896    2024
# 7897    2024
# 7898    2024
# Name: YEAR, Length: 7899, dtype: int32

# %%
df['MONTH']=df['Order Date'].dt.month
df['MONTH']
# Out:
# 0       11
# 1        6
# 2        8
# 3        3
# 4        4
#         ..
# 7894     9
# 7895     3
# 7896    12
# 7897     7
# 7898     4
# Name: MONTH, Length: 7899, dtype: int32

# %%
df['DAY']=df['Order Date'].dt.day
df['DAY']
# Out:
# 0        6
# 1       17
# 2       17
# 3       27
# 4        8
#         ..
# 7894    27
# 7895    16
# 7896     2
# 7897    29
# 7898     8
# Name: DAY, Length: 7899, dtype: int32

# %%
msales=df.groupby('Month')['Sales Profit'].sum()

# %%
msales.plot(kind='line', xlabel='Month')
# Out:
# <Axes: xlabel='Month'>

# %%
msales.plot(kind='bar', xlabel='Month')
# Out:
# <Axes: xlabel='Month'>

# %%
csales=df.groupby('Country')['Sales Profit'].sum()
csales
# Out:
# Country
# India    25045133.2
# Name: Sales Profit, dtype: float64

# %%
avgsales=df.groupby('Product ID')['Sales Profit'].mean().sort_values(ascending=False)
avgsales
# Out:
# Product ID
# 808    5702.800000
# 935    5505.377778
# 475    5480.600000
# 889    5197.333333
# 898    5182.133333
#           ...
# 257    1411.920000
# 978    1175.900000
# 582    1143.800000
# 658    1100.720000
# 439     819.733333
# Name: Sales Profit, Length: 796, dtype: float64

# %%
df['Clothing Type']=df['Clothing Type'].str.upper()
df['Clothing Type']
# Out:
# 0        DRESSES
# 1         SKIRTS
# 2        HOODIES
# 3        DRESSES
# 4        DRESSES
#           ...
# 7894       JEANS
# 7895     JACKETS
# 7896    T-SHIRTS
# 7897       SHOES
# 7898      SHIRTS
# Name: Clothing Type, Length: 7899, dtype: object
